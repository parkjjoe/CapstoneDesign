# %%
import tensorflow as tf
from tensorflow.keras import layers

def conv_block(input_tensor, num_filters, strides=(2, 2)):
    x = layers.Conv2D(num_filters, (1, 1), strides=strides)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(num_filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(4*num_filters, (1, 1))(x)
    x = layers.BatchNormalization()(x)

    shortcut = layers.Conv2D(4*num_filters, (1, 1), strides=strides)(input_tensor)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([shortcut, x])
    x = layers.Activation('relu')(x)
    return x

def identity_block(input_tensor, num_filters):
    x = layers.Conv2D(num_filters, (1, 1))(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(num_filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(4*num_filters, (1, 1))(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([input_tensor, x])
    x = layers.Activation('relu')(x)
    return x

def ResNet50():
    inputs = tf.keras.Input(shape=(224, 224, 3))

    x = layers.ZeroPadding2D((3, 3))(inputs)
    x = layers.Conv2D(64, (7, 7), strides=(2, 2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2))(x)

    x = conv_block(x, 64, strides=(1, 1))
    x = identity_block(x, 64)
    x = identity_block(x, 64)

    x = conv_block(x, 128)
    x = identity_block(x, 128)
    x = identity_block(x, 128)
    x = identity_block(x, 128)

    x = conv_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)

    x = conv_block(x, 512)
    x = identity_block(x, 512)
    x = identity_block(x, 512)

    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(1000, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    return model

model = ResNet50()
model.summary()

# %%
import tensorflow as tf
from tensorflow.keras import layers

def identity_block(input_tensor, kernel_size, filters):
    filters1, filters2, filters3 = filters

    x = layers.Conv2D(filters1, (1, 1))(input_tensor)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, padding='same')(x)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1))(x)
    x = layers.BatchNormalization(axis=3)(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, strides=(2, 2)):
    filters1, filters2, filters3 = filters

    x = layers.Conv2D(filters1, (1, 1), strides=strides)(input_tensor)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, padding='same')(x)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1))(x)
    x = layers.BatchNormalization(axis=3)(x)

    shortcut = layers.Conv2D(filters3, (1, 1), strides=strides)(input_tensor)
    shortcut = layers.BatchNormalization(axis=3)(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def ResNet50(input_shape=(224, 224, 3), classes=1000):
    img_input = layers.Input(shape=input_shape)

    x = layers.ZeroPadding2D(padding=(3, 3))(img_input)
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='valid')(x)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2))(x)

    x = conv_block(x, 3, [64, 64, 256], strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256])
    x = identity_block(x, 3, [64, 64, 256])

    x = conv_block(x, 3, [128, 128, 512])
    x = identity_block(x, 3, [128, 128, 512])
    x = identity_block(x, 3, [128, 128, 512])
    x = identity_block(x, 3, [128, 128, 512])

    x = conv_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])

    x = conv_block(x, 3, [512, 512, 2048])
    x = identity_block(x, 3, [512, 512, 2048])
    x = identity_block(x, 3, [512, 512, 2048])

    x = layers.GlobalAveragePooling2D(name='avg_pool')(x)
    x = layers.Dense(classes, activation='softmax')(x)

    model = tf.keras.Model(img_input, x)

    return model

model = ResNet50(input_shape=(224, 224, 3), classes=1000)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_1 (ZeroPadding2  (None, 230, 230, 3)  0          ['input_4[0][0]']
#  D)
#
#  conv2d_53 (Conv2D)             (None, 112, 112, 64  9472        ['zero_padding2d_1[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 112, 112, 64  256        ['conv2d_53[0][0]']
#  ormalization)                  )
#
#  activation_147 (Activation)    (None, 112, 112, 64  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 55, 55, 64)  0           ['activation_147[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 55, 55, 64)   4160        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 55, 55, 64)  256         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_148 (Activation)    (None, 55, 55, 64)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 55, 55, 64)   36928       ['activation_148[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 55, 55, 64)  256         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_149 (Activation)    (None, 55, 55, 64)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 55, 55, 256)  16640       ['activation_149[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 55, 55, 256)  16640       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 55, 55, 256)  1024       ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 55, 55, 256)  1024       ['conv2d_57[0][0]']
#  ormalization)
#
#  add_48 (Add)                   (None, 55, 55, 256)  0           ['batch_normalization_56[0][0]',
#                                                                   'batch_normalization_57[0][0]']
#
#  activation_150 (Activation)    (None, 55, 55, 256)  0           ['add_48[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 55, 55, 64)   16448       ['activation_150[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 55, 55, 64)  256         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_151 (Activation)    (None, 55, 55, 64)   0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 55, 55, 64)   36928       ['activation_151[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 55, 55, 64)  256         ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_152 (Activation)    (None, 55, 55, 64)   0           ['batch_normalization_59[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 55, 55, 256)  16640       ['activation_152[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 55, 55, 256)  1024       ['conv2d_60[0][0]']
#  ormalization)
#
#  add_49 (Add)                   (None, 55, 55, 256)  0           ['batch_normalization_60[0][0]',
#                                                                   'activation_150[0][0]']
#
#  activation_153 (Activation)    (None, 55, 55, 256)  0           ['add_49[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 55, 55, 64)   16448       ['activation_153[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 55, 55, 64)  256         ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_154 (Activation)    (None, 55, 55, 64)   0           ['batch_normalization_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 55, 55, 64)   36928       ['activation_154[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 55, 55, 64)  256         ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_155 (Activation)    (None, 55, 55, 64)   0           ['batch_normalization_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 55, 55, 256)  16640       ['activation_155[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 55, 55, 256)  1024       ['conv2d_63[0][0]']
#  ormalization)
#
#  add_50 (Add)                   (None, 55, 55, 256)  0           ['batch_normalization_63[0][0]',
#                                                                   'activation_153[0][0]']
#
#  activation_156 (Activation)    (None, 55, 55, 256)  0           ['add_50[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 28, 28, 128)  32896       ['activation_156[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 28, 28, 128)  512        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_157 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_157[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 28, 28, 128)  512        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_158 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_158[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_156[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_66[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_67[0][0]']
#  ormalization)
#
#  add_51 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_66[0][0]',
#                                                                   'batch_normalization_67[0][0]']
#
#  activation_159 (Activation)    (None, 28, 28, 512)  0           ['add_51[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_159[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 28, 28, 128)  512        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_160 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_160[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 28, 28, 128)  512        ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_161 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_69[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_161[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_70[0][0]']
#  ormalization)
#
#  add_52 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_70[0][0]',
#                                                                   'activation_159[0][0]']
#
#  activation_162 (Activation)    (None, 28, 28, 512)  0           ['add_52[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_162[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 28, 28, 128)  512        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_163 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_163[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 28, 28, 128)  512        ['conv2d_72[0][0]']
#  ormalization)
#
#  activation_164 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_72[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_164[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_73[0][0]']
#  ormalization)
#
#  add_53 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_73[0][0]',
#                                                                   'activation_162[0][0]']
#
#  activation_165 (Activation)    (None, 28, 28, 512)  0           ['add_53[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_165[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 28, 28, 128)  512        ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_166 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_166[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 28, 28, 128)  512        ['conv2d_75[0][0]']
#  ormalization)
#
#  activation_167 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_75[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_167[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_76[0][0]']
#  ormalization)
#
#  add_54 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_76[0][0]',
#                                                                   'activation_165[0][0]']
#
#  activation_168 (Activation)    (None, 28, 28, 512)  0           ['add_54[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 14, 14, 256)  131328      ['activation_168[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_169 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_77[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_169[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_78[0][0]']
#  ormalization)
#
#  activation_170 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_78[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_170[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_168[0][0]']
#                                 )
#
#  batch_normalization_79 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_79[0][0]']
#  ormalization)                  )
#
#  batch_normalization_80 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_80[0][0]']
#  ormalization)                  )
#
#  add_55 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_79[0][0]',
#                                 )                                 'batch_normalization_80[0][0]']
#
#  activation_171 (Activation)    (None, 14, 14, 1024  0           ['add_55[0][0]']
#                                 )
#
#  conv2d_81 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_171[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_172 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_81[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_172[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_82[0][0]']
#  ormalization)
#
#  activation_173 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_82[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_173[0][0]']
#                                 )
#
#  batch_normalization_83 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_83[0][0]']
#  ormalization)                  )
#
#  add_56 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_83[0][0]',
#                                 )                                 'activation_171[0][0]']
#
#  activation_174 (Activation)    (None, 14, 14, 1024  0           ['add_56[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_174[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_175 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_84[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_175[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_176 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_85[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_176[0][0]']
#                                 )
#
#  batch_normalization_86 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_86[0][0]']
#  ormalization)                  )
#
#  add_57 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_86[0][0]',
#                                 )                                 'activation_174[0][0]']
#
#  activation_177 (Activation)    (None, 14, 14, 1024  0           ['add_57[0][0]']
#                                 )
#
#  conv2d_87 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_177[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_87[0][0]']
#  ormalization)
#
#  activation_178 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_87[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_178[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_179 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_88[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_179[0][0]']
#                                 )
#
#  batch_normalization_89 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_89[0][0]']
#  ormalization)                  )
#
#  add_58 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_89[0][0]',
#                                 )                                 'activation_177[0][0]']
#
#  activation_180 (Activation)    (None, 14, 14, 1024  0           ['add_58[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_180[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_181 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_90[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_181[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_91[0][0]']
#  ormalization)
#
#  activation_182 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_91[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_182[0][0]']
#                                 )
#
#  batch_normalization_92 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_92[0][0]']
#  ormalization)                  )
#
#  add_59 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_92[0][0]',
#                                 )                                 'activation_180[0][0]']
#
#  activation_183 (Activation)    (None, 14, 14, 1024  0           ['add_59[0][0]']
#                                 )
#
#  conv2d_93 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_183[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_184 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_93[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_184[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_185 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_185[0][0]']
#                                 )
#
#  batch_normalization_95 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_95[0][0]']
#  ormalization)                  )
#
#  add_60 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_95[0][0]',
#                                 )                                 'activation_183[0][0]']
#
#  activation_186 (Activation)    (None, 14, 14, 1024  0           ['add_60[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 7, 7, 512)    524800      ['activation_186[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_187 (Activation)    (None, 7, 7, 512)    0           ['batch_normalization_96[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_187[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_188 (Activation)    (None, 7, 7, 512)    0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_188[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_186[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_98[0][0]']
#  ormalization)
#
#  batch_normalization_99 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_99[0][0]']
#  ormalization)
#
#  add_61 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_98[0][0]',
#                                                                   'batch_normalization_99[0][0]']
#
#  activation_189 (Activation)    (None, 7, 7, 2048)   0           ['add_61[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 7, 7, 512)    1049088     ['activation_189[0][0]']
#
#  batch_normalization_100 (Batch  (None, 7, 7, 512)   2048        ['conv2d_100[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 7, 7, 512)    0           ['batch_normalization_100[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 7, 7, 512)    2359808     ['activation_190[0][0]']
#
#  batch_normalization_101 (Batch  (None, 7, 7, 512)   2048        ['conv2d_101[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 7, 7, 512)    0           ['batch_normalization_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 2048)   1050624     ['activation_191[0][0]']
#
#  batch_normalization_102 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_102[0][0]']
#  Normalization)
#
#  add_62 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_102[0][0]',
#                                                                   'activation_189[0][0]']
#
#  activation_192 (Activation)    (None, 7, 7, 2048)   0           ['add_62[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 7, 7, 512)    1049088     ['activation_192[0][0]']
#
#  batch_normalization_103 (Batch  (None, 7, 7, 512)   2048        ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 7, 7, 512)    0           ['batch_normalization_103[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 7, 7, 512)    2359808     ['activation_193[0][0]']
#
#  batch_normalization_104 (Batch  (None, 7, 7, 512)   2048        ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 7, 7, 512)    0           ['batch_normalization_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 7, 7, 2048)   1050624     ['activation_194[0][0]']
#
#  batch_normalization_105 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_105[0][0]']
#  Normalization)
#
#  add_63 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_105[0][0]',
#                                                                   'activation_192[0][0]']
#
#  activation_195 (Activation)    (None, 7, 7, 2048)   0           ['add_63[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['activation_195[0][0]']
#  2D)
#
#  dense_1 (Dense)                (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras import layers

def identity_block(input_tensor, kernel_size, filters, stage, block):
    filters1, filters2, filters3 = filters

    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = layers.Conv2D(filters1, (1, 1), name=conv_name_base + '2a')(input_tensor)
    x = layers.BatchNormalization(axis=3, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size,
               padding='same', name=conv_name_base + '2b')(x)
    x = layers.BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1), name=conv_name_base + '2c')(x)
    x = layers.BatchNormalization(axis=3, name=bn_name_base + '2c')(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=(2, 2)):
    filters1, filters2, filters3 = filters

    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = layers.Conv2D(filters1, (1, 1), strides=strides,
               name=conv_name_base + '2a')(input_tensor)
    x = layers.BatchNormalization(axis=3, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, padding='same',
               name=conv_name_base + '2b')(x)
    x = layers.BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1), name=conv_name_base + '2c')(x)
    x = layers.BatchNormalization(axis=3, name=bn_name_base + '2c')(x)

    shortcut = layers.Conv2D(filters3, (1, 1), strides=strides,
                      name=conv_name_base + '1')(input_tensor)
    shortcut = layers.BatchNormalization(axis=3, name=bn_name_base + '1')(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def ResNet50(input_shape=(224, 224, 3), classes=1000):
    img_input = layers.Input(shape=input_shape)

    x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(img_input)
    x = layers.Conv2D(64, (7, 7),
                      strides=(2, 2),
                      padding='valid',
                      name='conv1')(x)
    x = layers.BatchNormalization(axis=3, name='bn_conv1')(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2))(x)

    x = conv_block(x, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='b')
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='c')

    x = conv_block(x, 3, [128, 128, 512], stage=3, block='a')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='b')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='c')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='d')

    x = conv_block(x, 3, [256, 256, 1024], stage=4, block='a')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='b')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='c')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='d')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='e')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='f')

    x = conv_block(x, 3, [512, 512, 2048], stage=5, block='a')
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block='b')
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block='c')

    x = layers.GlobalAveragePooling2D(name='avg_pool')(x)
    x = layers.Dense(classes, activation='softmax', name='fc' + str(classes))(x)

    model = tf.keras.Model(img_input, x, name='resnet50')

    return model

model = ResNet50(input_shape=(224, 224, 3), classes=1000)
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_3[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation_98 (Activation)     (None, 112, 112, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 55, 55, 64)  0           ['activation_98[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 55, 55, 64)   4160        ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_99 (Activation)     (None, 55, 55, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_99[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_100 (Activation)    (None, 55, 55, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_100[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 55, 55, 256)  16640       ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 55, 55, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add_32 (Add)                   (None, 55, 55, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_101 (Activation)    (None, 55, 55, 256)  0           ['add_32[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_101[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_102 (Activation)    (None, 55, 55, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_102[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_103 (Activation)    (None, 55, 55, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_103[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_33 (Add)                   (None, 55, 55, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_101[0][0]']
#
#  activation_104 (Activation)    (None, 55, 55, 256)  0           ['add_33[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_104[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_105 (Activation)    (None, 55, 55, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_105[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_106 (Activation)    (None, 55, 55, 64)   0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_106[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_34 (Add)                   (None, 55, 55, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_104[0][0]']
#
#  activation_107 (Activation)    (None, 55, 55, 256)  0           ['add_34[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 28, 28, 128)  32896       ['activation_107[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_108 (Activation)    (None, 28, 28, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_108[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_109 (Activation)    (None, 28, 28, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_109[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 28, 28, 512)  131584      ['activation_107[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 28, 28, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_35 (Add)                   (None, 28, 28, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_110 (Activation)    (None, 28, 28, 512)  0           ['add_35[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_110[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_111 (Activation)    (None, 28, 28, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_111[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_112 (Activation)    (None, 28, 28, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_112[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_36 (Add)                   (None, 28, 28, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_110[0][0]']
#
#  activation_113 (Activation)    (None, 28, 28, 512)  0           ['add_36[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_113[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_114 (Activation)    (None, 28, 28, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_114[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_115 (Activation)    (None, 28, 28, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_115[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_37 (Add)                   (None, 28, 28, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_113[0][0]']
#
#  activation_116 (Activation)    (None, 28, 28, 512)  0           ['add_37[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_116[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_117 (Activation)    (None, 28, 28, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_117[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_118 (Activation)    (None, 28, 28, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_118[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_38 (Add)                   (None, 28, 28, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_116[0][0]']
#
#  activation_119 (Activation)    (None, 28, 28, 512)  0           ['add_38[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 14, 14, 256)  131328      ['activation_119[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_120 (Activation)    (None, 14, 14, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_120[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_121 (Activation)    (None, 14, 14, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_121[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 14, 14, 1024  525312      ['activation_119[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 14, 14, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_39 (Add)                   (None, 14, 14, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_122 (Activation)    (None, 14, 14, 1024  0           ['add_39[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_122[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_123 (Activation)    (None, 14, 14, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_123[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_124 (Activation)    (None, 14, 14, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_124[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#
#  add_40 (Add)                   (None, 14, 14, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_122[0][0]']
#
#  activation_125 (Activation)    (None, 14, 14, 1024  0           ['add_40[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_125[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_126 (Activation)    (None, 14, 14, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_126[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_127 (Activation)    (None, 14, 14, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_127[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_41 (Add)                   (None, 14, 14, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_125[0][0]']
#
#  activation_128 (Activation)    (None, 14, 14, 1024  0           ['add_41[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_128[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_129 (Activation)    (None, 14, 14, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_129[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_130 (Activation)    (None, 14, 14, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_130[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_42 (Add)                   (None, 14, 14, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_128[0][0]']
#
#  activation_131 (Activation)    (None, 14, 14, 1024  0           ['add_42[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_131[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_132 (Activation)    (None, 14, 14, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_132[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_133 (Activation)    (None, 14, 14, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_133[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_43 (Add)                   (None, 14, 14, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_131[0][0]']
#
#  activation_134 (Activation)    (None, 14, 14, 1024  0           ['add_43[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_134[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_135 (Activation)    (None, 14, 14, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_135[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_136 (Activation)    (None, 14, 14, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_136[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_44 (Add)                   (None, 14, 14, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_134[0][0]']
#
#  activation_137 (Activation)    (None, 14, 14, 1024  0           ['add_44[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 7, 7, 512)    524800      ['activation_137[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_138 (Activation)    (None, 7, 7, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_138[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_139 (Activation)    (None, 7, 7, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_139[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 7, 7, 2048)   2099200     ['activation_137[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 7, 7, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_45 (Add)                   (None, 7, 7, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_140 (Activation)    (None, 7, 7, 2048)   0           ['add_45[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_140[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_141 (Activation)    (None, 7, 7, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_141[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_142 (Activation)    (None, 7, 7, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_142[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_46 (Add)                   (None, 7, 7, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_140[0][0]']
#
#  activation_143 (Activation)    (None, 7, 7, 2048)   0           ['add_46[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_143[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_144 (Activation)    (None, 7, 7, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_144[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_145 (Activation)    (None, 7, 7, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_145[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_47 (Add)                   (None, 7, 7, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_143[0][0]']
#
#  activation_146 (Activation)    (None, 7, 7, 2048)   0           ['add_47[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['activation_146[0][0]']
#  2D)
#
#  fc1000 (Dense)                 (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras import layers

def identity_block(input_tensor, kernel_size, filters):
    filters1, filters2, filters3 = filters

    x = layers.Conv2D(filters1, (1, 1))(input_tensor)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, padding='same')(x)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1))(x)
    x = layers.BatchNormalization(axis=3)(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, strides=(2, 2)):
    filters1, filters2, filters3 = filters

    x = layers.Conv2D(filters1, (1, 1), strides=strides)(input_tensor)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, padding='same')(x)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1))(x)
    x = layers.BatchNormalization(axis=3)(x)

    shortcut = layers.Conv2D(filters3, (1, 1), strides=strides)(input_tensor)
    shortcut = layers.BatchNormalization(axis=3)(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def ResNet50(input_shape=(224, 224, 3), classes=1000):
    img_input = layers.Input(shape=input_shape)

    x = layers.ZeroPadding2D(padding=(3, 3))(img_input)
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='valid')(x)
    x = layers.BatchNormalization(axis=3)(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x) # MaxPooling2D를 Conv2D로 변경

    x = conv_block(x, 3, [64, 64, 256], strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256])
    x = identity_block(x, 3, [64, 64, 256])

    x = conv_block(x, 3, [128, 128, 512])
    x = identity_block(x, 3, [128, 128, 512])
    x = identity_block(x, 3, [128, 128, 512])
    x = identity_block(x, 3, [128, 128, 512])

    x = conv_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])

    x = conv_block(x, 3, [512, 512, 2048])
    x = identity_block(x, 3, [512, 512, 2048])
    x = identity_block(x, 3, [512, 512, 2048])

    x = layers.Conv2D(classes, (7, 7), strides=(1, 1), padding='valid')(x) # GlobalAveragePooling2D를 Conv2D로 변경 후 softmax 적용
    x = layers.Flatten()(x)
    x = layers.Activation('softmax')(x)
#    x = layers.Dense(1000, activation='relu')(x)
#    x = layers.Dropout(0.5)(x)
#    x = layers.Dense(512, activation='relu')(x)
#    x = layers.Dropout(0.5)(x)

    model = tf.keras.Model(img_input, x)

    return model

model = ResNet50(input_shape=(224, 224, 3), classes=1000)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   36928       ['activation[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   4160        ['conv2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 256)  16640       ['activation_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 256)  16640       ['conv2d_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 256)  0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_3 (Activation)      (None, 56, 56, 256)  0           ['add[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 64)   16448       ['activation_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 256)  16640       ['activation_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_7[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 56, 56, 256)  0           ['add_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 64)   16448       ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 256)  16640       ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_10[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 56, 56, 256)  0           ['add_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  32896       ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_13[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_12[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_18[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_17[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_15[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_21[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_20[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 128)  512        ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_24[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_23[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 256)  131328      ['activation_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_26[0][0]',
#                                 )                                 'batch_normalization_27[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_24[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_25[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_30[0][0]',
#                                 )                                 'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_27[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_33[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_30[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_31[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_36[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_33[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_34[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_39[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_36[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_37[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_42[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 7, 7, 512)    524800      ['activation_39[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_40[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_39[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_47[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_45[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_42[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_43[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_44[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_50[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_49[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_45[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_46[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_47[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_53[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_52[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 1, 1, 1000)   100353000   ['activation_48[0][0]']
#
#  flatten (Flatten)              (None, 1000)         0           ['conv2d_54[0][0]']
#
#  activation_49 (Activation)     (None, 1000)         0           ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 123,977,640
# Trainable params: 123,924,520
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
