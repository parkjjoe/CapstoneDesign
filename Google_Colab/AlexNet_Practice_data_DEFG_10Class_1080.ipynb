# %%
# !pip install tensorflow==2.6.0
import tensorflow as tf
print(tf.__version__)

# %%
# !pip install tensorflow==2.6.0 keras==2.6.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import metrics
import tensorflow as tf

# 데이터 경로
train_dir = '/content/drive/MyDrive/data_DEFG_10Class_1080/train'
val_dir = '/content/drive/MyDrive/data_DEFG_10Class_1080/val'

# 이미지 크기 및 채널
img_size = (227, 227)
img_channel = 3

# 이미지 데이터 전처리
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    zoom_range=0.2,
    shear_range=10,
    channel_shift_range=50,
    brightness_range=(0.8,1.8),
    fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=16,
    class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=16,
    class_mode='categorical')

def create_alexnet(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(96, kernel_size=(11, 11), strides=(4, 4), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(Conv2D(256, kernel_size=(5, 5), strides=(1, 1), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(Conv2D(384, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
    model.add(Conv2D(384, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    return model

model = create_alexnet((img_size[0], img_size[1], img_channel), 10)

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', metrics.Precision(), metrics.Recall()])

# 스케줄러 함수 정의
#def scheduler(epoch, lr):
#    if epoch < 10:
#        return lr
#    else:
#        return lr * tf.math.exp(-0.1)

# 학습률 스케줄링 콜백 설정
#lr_scheduler = LearningRateScheduler(scheduler)

# 체크포인트를 저장할 경로
checkpoint_filepath = '/content/drive/MyDrive/checkpoint/model-{epoch:03d}.h5'

# 체크포인트 콜백 설정
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1)

# 모델 학습
history = model.fit(train_generator,
          steps_per_epoch=len(train_generator),
          epochs=30,
          validation_data=validation_generator,
          validation_steps=len(validation_generator),
          callbacks=[checkpoint_callback])
# Out:
# Found 14196 images belonging to 10 classes.
# Found 4069 images belonging to 10 classes.
# Epoch 1/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2982 - accuracy: 0.1236 - precision_1: 0.1176 - recall_1: 1.4088e-04
# Epoch 1: val_loss improved from inf to 2.25906, saving model to /content/drive/MyDrive/checkpoint/model-001.h5
# 888/888 [==============================] - 418s 468ms/step - loss: 2.2982 - accuracy: 0.1236 - precision_1: 0.1176 - recall_1: 1.4088e-04 - val_loss: 2.2591 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2539 - accuracy: 0.1271 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 2: val_loss improved from 2.25906 to 2.25742, saving model to /content/drive/MyDrive/checkpoint/model-002.h5
# 888/888 [==============================] - 413s 465ms/step - loss: 2.2539 - accuracy: 0.1271 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2574 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2536 - accuracy: 0.1260 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 3: val_loss did not improve from 2.25742
# 888/888 [==============================] - 410s 462ms/step - loss: 2.2536 - accuracy: 0.1260 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2583 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2546 - accuracy: 0.1215 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 4: val_loss improved from 2.25742 to 2.25700, saving model to /content/drive/MyDrive/checkpoint/model-004.h5
# 888/888 [==============================] - 416s 468ms/step - loss: 2.2546 - accuracy: 0.1215 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2570 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2531 - accuracy: 0.1244 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 5: val_loss did not improve from 2.25700
# 888/888 [==============================] - 414s 467ms/step - loss: 2.2531 - accuracy: 0.1244 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2584 - val_accuracy: 0.1246 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2531 - accuracy: 0.1257 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 6: val_loss did not improve from 2.25700
# 888/888 [==============================] - 413s 465ms/step - loss: 2.2531 - accuracy: 0.1257 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2581 - val_accuracy: 0.1283 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2533 - accuracy: 0.1288 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 7: val_loss did not improve from 2.25700
# 888/888 [==============================] - 418s 470ms/step - loss: 2.2533 - accuracy: 0.1288 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2597 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2532 - accuracy: 0.1291 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 8: val_loss did not improve from 2.25700
# 888/888 [==============================] - 411s 462ms/step - loss: 2.2532 - accuracy: 0.1291 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2579 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2532 - accuracy: 0.1243 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 9: val_loss did not improve from 2.25700
# 888/888 [==============================] - 415s 468ms/step - loss: 2.2532 - accuracy: 0.1243 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2577 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2532 - accuracy: 0.1252 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 10: val_loss improved from 2.25700 to 2.25659, saving model to /content/drive/MyDrive/checkpoint/model-010.h5
# 888/888 [==============================] - 421s 474ms/step - loss: 2.2532 - accuracy: 0.1252 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2566 - val_accuracy: 0.1283 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2536 - accuracy: 0.1237 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 11: val_loss did not improve from 2.25659
# 888/888 [==============================] - 421s 474ms/step - loss: 2.2536 - accuracy: 0.1237 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2574 - val_accuracy: 0.1207 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 12/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2532 - accuracy: 0.1250 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 12: val_loss did not improve from 2.25659
# 888/888 [==============================] - 417s 469ms/step - loss: 2.2532 - accuracy: 0.1250 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2581 - val_accuracy: 0.1283 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 13/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2533 - accuracy: 0.1279 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 13: val_loss did not improve from 2.25659
# 888/888 [==============================] - 414s 466ms/step - loss: 2.2533 - accuracy: 0.1279 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2575 - val_accuracy: 0.1207 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 14/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2527 - accuracy: 0.1214 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 14: val_loss did not improve from 2.25659
# 888/888 [==============================] - 417s 469ms/step - loss: 2.2527 - accuracy: 0.1214 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2580 - val_accuracy: 0.1229 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 15/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2535 - accuracy: 0.1224 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 15: val_loss did not improve from 2.25659
# 888/888 [==============================] - 410s 462ms/step - loss: 2.2535 - accuracy: 0.1224 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2569 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2522 - accuracy: 0.1279 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 16: val_loss did not improve from 2.25659
# 888/888 [==============================] - 414s 466ms/step - loss: 2.2522 - accuracy: 0.1279 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2571 - val_accuracy: 0.1229 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 17/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2526 - accuracy: 0.1245 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 17: val_loss did not improve from 2.25659
# 888/888 [==============================] - 422s 476ms/step - loss: 2.2526 - accuracy: 0.1245 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2576 - val_accuracy: 0.1229 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 18/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2526 - accuracy: 0.1247 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 18: val_loss did not improve from 2.25659
# 888/888 [==============================] - 426s 480ms/step - loss: 2.2526 - accuracy: 0.1247 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2570 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 19/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2522 - accuracy: 0.1264 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 19: val_loss did not improve from 2.25659
# 888/888 [==============================] - 419s 472ms/step - loss: 2.2522 - accuracy: 0.1264 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2572 - val_accuracy: 0.1229 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 20/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2526 - accuracy: 0.1240 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 20: val_loss did not improve from 2.25659
# 888/888 [==============================] - 416s 468ms/step - loss: 2.2526 - accuracy: 0.1240 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2571 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 21/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2525 - accuracy: 0.1238 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 21: val_loss did not improve from 2.25659
# 888/888 [==============================] - 416s 468ms/step - loss: 2.2525 - accuracy: 0.1238 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2570 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 22/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2525 - accuracy: 0.1233 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 22: val_loss did not improve from 2.25659
# 888/888 [==============================] - 406s 458ms/step - loss: 2.2525 - accuracy: 0.1233 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2572 - val_accuracy: 0.1246 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 23/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2525 - accuracy: 0.1241 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 23: val_loss did not improve from 2.25659
# 888/888 [==============================] - 410s 462ms/step - loss: 2.2525 - accuracy: 0.1241 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2571 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 24/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2520 - accuracy: 0.1283 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 24: val_loss did not improve from 2.25659
# 888/888 [==============================] - 414s 466ms/step - loss: 2.2520 - accuracy: 0.1283 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2569 - val_accuracy: 0.1229 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 25/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2518 - accuracy: 0.1212 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 25: val_loss did not improve from 2.25659
# 888/888 [==============================] - 417s 470ms/step - loss: 2.2518 - accuracy: 0.1212 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2569 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 26/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2522 - accuracy: 0.1260 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 26: val_loss did not improve from 2.25659
# 888/888 [==============================] - 416s 468ms/step - loss: 2.2522 - accuracy: 0.1260 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2573 - val_accuracy: 0.1229 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 27/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2520 - accuracy: 0.1287 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 27: val_loss did not improve from 2.25659
# 888/888 [==============================] - 413s 465ms/step - loss: 2.2520 - accuracy: 0.1287 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2571 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 28/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2518 - accuracy: 0.1269 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 28: val_loss did not improve from 2.25659
# 888/888 [==============================] - 407s 459ms/step - loss: 2.2518 - accuracy: 0.1269 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2581 - val_accuracy: 0.1283 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 29/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2520 - accuracy: 0.1239 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 29: val_loss did not improve from 2.25659
# 888/888 [==============================] - 406s 457ms/step - loss: 2.2520 - accuracy: 0.1239 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2569 - val_accuracy: 0.1229 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 30/30
# 888/888 [==============================] - ETA: 0s - loss: 2.2521 - accuracy: 0.1259 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00
# Epoch 30: val_loss did not improve from 2.25659
# 888/888 [==============================] - 405s 456ms/step - loss: 2.2521 - accuracy: 0.1259 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 2.2570 - val_accuracy: 0.1241 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import metrics
import tensorflow as tf

# 데이터 경로
train_dir = '/content/drive/MyDrive/data_all/train'
val_dir = '/content/drive/MyDrive/data_all/val'

# 이미지 크기 및 채널
img_size = (224, 224)
img_channel = 3

# 이미지 데이터 전처리
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    zoom_range=0.2,
    shear_range=10,
    channel_shift_range=50,
    brightness_range=(0.8,1.8),
    fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

# ResNet50 모델 불러오기
resnet = ResNet50(input_shape=(img_size[0], img_size[1], img_channel), weights=None, include_top=False)

# 새로운 분류층 추가
x = resnet.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
predictions = layers.Dense(16, activation='softmax')(x) # 클래스 개수만큼 조정

model = models.Model(inputs=resnet.input, outputs=predictions)

# 옵티마이저 생성
optimizer = tf.keras.optimizers.Adam(learning_rate=1.6530e-04)

# 이전에 저장된 모델 가중치 불러오기
model.load_weights('/content/drive/MyDrive/checkpoint/checkpoints/model-028.h5') # 경로 작성

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy', metrics.Precision(), metrics.Recall()])

# 스케줄러 함수 정의
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

# 학습률 스케줄링 콜백 설정
lr_scheduler = LearningRateScheduler(scheduler)

# 체크포인트를 저장할 경로
checkpoint_filepath = '/content/drive/MyDrive/checkpoint/checkpoints/model-{epoch:03d}.h5'

# 체크포인트 콜백 설정
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    save_best_only=True, # 가장 성능이 좋은 가중치 저장 여부
    save_weights_only=True, # 모델, 가중치 저장 선택
    verbose=1)

# 학습 이어서 시작
history = model.fit(train_generator,
          steps_per_epoch=len(train_generator),
          epochs=30,
          validation_data=validation_generator,
          validation_steps=len(validation_generator),
          callbacks=[checkpoint_callback, lr_scheduler],
          initial_epoch=28) # initial_epoch = 이전에 중단된 epoch 숫자

# %%
import matplotlib.pyplot as plt

val_accuracy = [0.0633, 0.1247, 0.0937, 0.5093, 0.7972, 0.9871, 0.7835, 0.8470, 0.9924, 0.8866, 0.5740, 0.9976, 0.9429, 0.9992, 0.9994, 0.9139, 0.9973, 0.9988, 0.9433, 0.9935, 0.9976, 0.9994, 0.9802, 0.9994, 0.9994, 0.9992, 0.9863, 0.9994, 0.9998, 0.9998]
val_loss = [2.7814, 5.4298, 17.4214, 1.4944, 0.8378, 0.0323, 0.9265, 0.7361, 0.0292, 0.3111, 1.6086, 0.0085, 0.2497, 0.0032, 0.0057, 0.3580, 0.0085, 0.0061, 0.1761, 0.0235, 0.0067, 0.0017, 0.0843, 8.9025e-04, 8.8536e-04, 9.5349e-04, 0.0566, 7.5358e-04, 6.9298e-04, 4.2381e-04]

# 정확도 그래프
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.ylim(0, 1)
plt.show()

# 손실 그래프
plt.plot(val_loss, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0, 2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 학습 곡선 그리기
num_epochs = len(history.history['accuracy'])
epoch_range = np.arange(1, num_epochs + 1)

plt.plot(epoch_range, history.history['accuracy'])
plt.plot(epoch_range, history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(epoch_range, history.history['loss'])
plt.plot(epoch_range, history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 학습 곡선 그리기
num_epochs = len(history.history['accuracy'])
epoch_range = np.arange(1, num_epochs + 1)

plt.figure(figsize=(10, 5))
plt.plot(epoch_range, history.history['accuracy'])
plt.plot(epoch_range, history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(epoch_range, history.history['loss'])
plt.plot(epoch_range, history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(epoch_range, history.history['precision'])
plt.plot(epoch_range, history.history['val_precision'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(epoch_range, history.history['recall'])
plt.plot(epoch_range, history.history['val_recall'])
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# 구글 드라이브에 모델 저장
model.save('/content/drive/MyDrive/ResNet50_data_DEFG_10Class_1080.h5')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt

# 전체 테스트 데이터 세트 폴더 경로
test_dir = '/content/drive/MyDrive/data_DEFG_10Class_1080/test'

image_size = (224, 224)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=1,
    shuffle=False,
    class_mode='categorical')

# 저장된 모델 경로
model = load_model('/content/drive/MyDrive/ResNet50_data_DEFG_10Class_1080.h5')

# 분류 및 평가
Y_pred = model.predict(test_generator, steps=len(test_generator))
y_pred = np.argmax(Y_pred, axis=1)

true_labels = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# 출력
print('테스트 결과')
print('---------------------')
for i, filename in enumerate(test_generator.filenames):
    print('{} : {}'.format(filename, class_labels[y_pred[i]]))

accuracy = accuracy_score(true_labels, y_pred)
precision = precision_score(true_labels, y_pred, average='macro')
recall = recall_score(true_labels, y_pred, average='macro')
f1score = f1_score(true_labels, y_pred, average='macro')

print('---------------------')
print('정확도 : {:.5f}'.format(accuracy))
print('정밀도 : {:.5f}'.format(precision))
print('재현율 : {:.5f}'.format(recall))
print('F1-score : {:.5f}'.format(f1score))

# Confusion Matrix and Classification Report
cm = confusion_matrix(true_labels, y_pred)
print('Confusion Matrix')
print(cm)

# 각 클래스별 정밀도, 재현율, F1-score, 그리고 지지도(support, 샘플 수)를 계산
cr = classification_report(true_labels, y_pred, target_names=class_labels)
print('Classification Report')
print(cr)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt

# ABC 테스트 데이터 세트 폴더 경로
test_dir = '/content/drive/MyDrive/data_ABC_10Class_1080/test'

image_size = (224, 224)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=1,
    shuffle=False,
    class_mode='categorical')

# 저장된 모델 경로
model = load_model('/content/drive/MyDrive/ResNet50_data_DEFG_10Class_1080.h5')

# 분류 및 평가
Y_pred = model.predict(test_generator, steps=len(test_generator))
y_pred = np.argmax(Y_pred, axis=1)

true_labels = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# 출력
print('테스트 결과')
print('---------------------')
for i, filename in enumerate(test_generator.filenames):
    print('{} : {}'.format(filename, class_labels[y_pred[i]]))

accuracy = accuracy_score(true_labels, y_pred)
precision = precision_score(true_labels, y_pred, average='macro')
recall = recall_score(true_labels, y_pred, average='macro')
f1score = f1_score(true_labels, y_pred, average='macro')

print('---------------------')
print('정확도 : {:.5f}'.format(accuracy))
print('정밀도 : {:.5f}'.format(precision))
print('재현율 : {:.5f}'.format(recall))
print('F1-score : {:.5f}'.format(f1score))

# Confusion Matrix and Classification Report
cm = confusion_matrix(true_labels, y_pred)
print('Confusion Matrix')
print(cm)

# 각 클래스별 정밀도, 재현율, F1-score, 그리고 지지도(support, 샘플 수)를 계산
cr = classification_report(true_labels, y_pred, target_names=class_labels)
print('Classification Report')
print(cr)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt

# A 테스트 데이터 세트 폴더 경로
test_dir = '/content/drive/MyDrive/data_A_10Class_1080/test'

image_size = (224, 224)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=1,
    shuffle=False,
    class_mode='categorical')

# 저장된 모델 경로
model = load_model('/content/drive/MyDrive/ResNet50_data_DEFG_10Class_1080.h5')

# 분류 및 평가
Y_pred = model.predict(test_generator, steps=len(test_generator))
y_pred = np.argmax(Y_pred, axis=1)

true_labels = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# 출력
print('테스트 결과')
print('---------------------')
for i, filename in enumerate(test_generator.filenames):
    print('{} : {}'.format(filename, class_labels[y_pred[i]]))

accuracy = accuracy_score(true_labels, y_pred)
precision = precision_score(true_labels, y_pred, average='macro')
recall = recall_score(true_labels, y_pred, average='macro')
f1score = f1_score(true_labels, y_pred, average='macro')

print('---------------------')
print('정확도 : {:.5f}'.format(accuracy))
print('정밀도 : {:.5f}'.format(precision))
print('재현율 : {:.5f}'.format(recall))
print('F1-score : {:.5f}'.format(f1score))

# Confusion Matrix and Classification Report
cm = confusion_matrix(true_labels, y_pred)
print('Confusion Matrix')
print(cm)

# 각 클래스별 정밀도, 재현율, F1-score, 그리고 지지도(support, 샘플 수)를 계산
cr = classification_report(true_labels, y_pred, target_names=class_labels)
print('Classification Report')
print(cr)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt

# BC 테스트 데이터 세트 폴더 경로
test_dir = '/content/drive/MyDrive/data_BC_10Class_1080/test'

image_size = (224, 224)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=1,
    shuffle=False,
    class_mode='categorical')

# 저장된 모델 경로
model = load_model('/content/drive/MyDrive/ResNet50_data_DEFG_10Class_1080.h5')

# 분류 및 평가
Y_pred = model.predict(test_generator, steps=len(test_generator))
y_pred = np.argmax(Y_pred, axis=1)

true_labels = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# 출력
print('테스트 결과')
print('---------------------')
for i, filename in enumerate(test_generator.filenames):
    print('{} : {}'.format(filename, class_labels[y_pred[i]]))

accuracy = accuracy_score(true_labels, y_pred)
precision = precision_score(true_labels, y_pred, average='macro')
recall = recall_score(true_labels, y_pred, average='macro')
f1score = f1_score(true_labels, y_pred, average='macro')

print('---------------------')
print('정확도 : {:.5f}'.format(accuracy))
print('정밀도 : {:.5f}'.format(precision))
print('재현율 : {:.5f}'.format(recall))
print('F1-score : {:.5f}'.format(f1score))

# Confusion Matrix and Classification Report
cm = confusion_matrix(true_labels, y_pred)
print('Confusion Matrix')
print(cm)

# 각 클래스별 정밀도, 재현율, F1-score, 그리고 지지도(support, 샘플 수)를 계산
cr = classification_report(true_labels, y_pred, target_names=class_labels)
print('Classification Report')
print(cr)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt

# DE 테스트 데이터 세트 폴더 경로
test_dir = '/content/drive/MyDrive/data_DE_10Class_1080/test'

image_size = (224, 224)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=1,
    shuffle=False,
    class_mode='categorical')

# 저장된 모델 경로
model = load_model('/content/drive/MyDrive/ResNet50_data_DEFG_10Class_1080.h5')

# 분류 및 평가
Y_pred = model.predict(test_generator, steps=len(test_generator))
y_pred = np.argmax(Y_pred, axis=1)

true_labels = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# 출력
print('테스트 결과')
print('---------------------')
for i, filename in enumerate(test_generator.filenames):
    print('{} : {}'.format(filename, class_labels[y_pred[i]]))

accuracy = accuracy_score(true_labels, y_pred)
precision = precision_score(true_labels, y_pred, average='macro')
recall = recall_score(true_labels, y_pred, average='macro')
f1score = f1_score(true_labels, y_pred, average='macro')

print('---------------------')
print('정확도 : {:.5f}'.format(accuracy))
print('정밀도 : {:.5f}'.format(precision))
print('재현율 : {:.5f}'.format(recall))
print('F1-score : {:.5f}'.format(f1score))

# Confusion Matrix and Classification Report
cm = confusion_matrix(true_labels, y_pred)
print('Confusion Matrix')
print(cm)

# 각 클래스별 정밀도, 재현율, F1-score, 그리고 지지도(support, 샘플 수)를 계산
cr = classification_report(true_labels, y_pred, target_names=class_labels)
print('Classification Report')
print(cr)
