# %%
# !pip install tensorflow==2.6.0
import tensorflow as tf
print(tf.__version__)

# %%
# !pip install tensorflow==2.6.0 keras==2.6.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import metrics

# 데이터 경로
train_dir = '/content/drive/MyDrive/datasets2/train'
val_dir = '/content/drive/MyDrive/datasets2/val'

# 이미지 크기 및 채널
img_size = (224, 224)
img_channel = 3

# 이미지 데이터 전처리
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    brightness_range=(0.8,1.8),
    fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

# ResNet101 모델 불러오기
resnet = ResNet101(input_shape=(img_size[0], img_size[1], img_channel), weights='imagenet', include_top=False) # ImageNet으로 사전 학습된 가중치를 초기 가중치로 사용

# 새로운 분류층 추가
x = resnet.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
predictions = layers.Dense(4, activation='softmax')(x) # 클래스 개수만큼 조정

model = models.Model(inputs=resnet.input, outputs=predictions)

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 체크포인트를 저장할 경로
checkpoint_filepath = '/content/drive/MyDrive/checkpoints2-2/model-{epoch:03d}.h5'

# 체크포인트 콜백 설정
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    save_best_only=False, # 가장 성능이 좋은 가중치 저장 여부
    save_weights_only=True, # 모델, 가중치 저장 선택
    verbose=1)

# 조기 종료 콜백 설정
early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    patience=5, # val_loss가 최소 5 epoch 동안 개선되지 않으면 학습 중단
    restore_best_weights=True) # 가장 성능이 좋은 가중치 복원 여부

# 모델 학습
history = model.fit(train_generator,
          steps_per_epoch=len(train_generator),
          epochs=50,
          validation_data=validation_generator,
          validation_steps=len(validation_generator),
          callbacks=[checkpoint_callback, early_stopping_callback]) # 체크포인트, 조기 종료 인자 추가
# Out:
# Found 5503 images belonging to 4 classes.
# Found 1568 images belonging to 4 classes.
# Epoch 1/50
# 344/344 [==============================] - ETA: 0s - loss: 1.2742 - accuracy: 0.4081
# Epoch 1: saving model to /content/drive/MyDrive/checkpoints2-2/model-001.h5
# 344/344 [==============================] - 3653s 10s/step - loss: 1.2742 - accuracy: 0.4081 - val_loss: 3.6937 - val_accuracy: 0.2570
# Epoch 2/50
# 344/344 [==============================] - ETA: 0s - loss: 0.4721 - accuracy: 0.8223
# Epoch 2: saving model to /content/drive/MyDrive/checkpoints2-2/model-002.h5
# 344/344 [==============================] - 244s 710ms/step - loss: 0.4721 - accuracy: 0.8223 - val_loss: 1.4419 - val_accuracy: 0.2704
# Epoch 3/50
# 344/344 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.9535
# Epoch 3: saving model to /content/drive/MyDrive/checkpoints2-2/model-003.h5
# 344/344 [==============================] - 245s 711ms/step - loss: 0.1526 - accuracy: 0.9535 - val_loss: 9.2222 - val_accuracy: 0.3661
# Epoch 4/50
# 344/344 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9687
# Epoch 4: saving model to /content/drive/MyDrive/checkpoints2-2/model-004.h5
# 344/344 [==============================] - 246s 716ms/step - loss: 0.1014 - accuracy: 0.9687 - val_loss: 0.3916 - val_accuracy: 0.8272
# Epoch 5/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9824
# Epoch 5: saving model to /content/drive/MyDrive/checkpoints2-2/model-005.h5
# 344/344 [==============================] - 244s 709ms/step - loss: 0.0631 - accuracy: 0.9824 - val_loss: 14.0863 - val_accuracy: 0.4815
# Epoch 6/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9929
# Epoch 6: saving model to /content/drive/MyDrive/checkpoints2-2/model-006.h5
# 344/344 [==============================] - 243s 705ms/step - loss: 0.0241 - accuracy: 0.9929 - val_loss: 1.6452 - val_accuracy: 0.6441
# Epoch 7/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9835
# Epoch 7: saving model to /content/drive/MyDrive/checkpoints2-2/model-007.h5
# 344/344 [==============================] - 243s 706ms/step - loss: 0.0538 - accuracy: 0.9835 - val_loss: 0.0198 - val_accuracy: 0.9930
# Epoch 8/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9945
# Epoch 8: saving model to /content/drive/MyDrive/checkpoints2-2/model-008.h5
# 344/344 [==============================] - 244s 709ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 0.0045 - val_accuracy: 0.9981
# Epoch 9/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9827
# Epoch 9: saving model to /content/drive/MyDrive/checkpoints2-2/model-009.h5
# 344/344 [==============================] - 243s 707ms/step - loss: 0.0557 - accuracy: 0.9827 - val_loss: 0.8967 - val_accuracy: 0.7806
# Epoch 10/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9884
# Epoch 10: saving model to /content/drive/MyDrive/checkpoints2-2/model-010.h5
# 344/344 [==============================] - 247s 718ms/step - loss: 0.0405 - accuracy: 0.9884 - val_loss: 0.0021 - val_accuracy: 0.9987
# Epoch 11/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9985
# Epoch 11: saving model to /content/drive/MyDrive/checkpoints2-2/model-011.h5
# 344/344 [==============================] - 247s 719ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 2.1575 - val_accuracy: 0.7290
# Epoch 12/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9900
# Epoch 12: saving model to /content/drive/MyDrive/checkpoints2-2/model-012.h5
# 344/344 [==============================] - 244s 708ms/step - loss: 0.0395 - accuracy: 0.9900 - val_loss: 5.3546 - val_accuracy: 0.2411
# Epoch 13/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9944
# Epoch 13: saving model to /content/drive/MyDrive/checkpoints2-2/model-013.h5
# 344/344 [==============================] - 247s 719ms/step - loss: 0.0210 - accuracy: 0.9944 - val_loss: 0.1544 - val_accuracy: 0.9509
# Epoch 14/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9942
# Epoch 14: saving model to /content/drive/MyDrive/checkpoints2-2/model-014.h5
# 344/344 [==============================] - 246s 715ms/step - loss: 0.0190 - accuracy: 0.9942 - val_loss: 0.0039 - val_accuracy: 0.9981
# Epoch 15/50
# 344/344 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9951
# Epoch 15: saving model to /content/drive/MyDrive/checkpoints2-2/model-015.h5
# 344/344 [==============================] - 246s 716ms/step - loss: 0.0193 - accuracy: 0.9951 - val_loss: 0.6481 - val_accuracy: 0.7723

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101
from tensorflow.keras import layers, models
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

train_dir = '/content/drive/MyDrive/dataset/train'
val_dir = '/content/drive/MyDrive/dataset/val'

img_size = (224, 224)
img_channel = 3

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    brightness_range=(0.8,1.8),
    fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

resnet = ResNet101(input_shape=(img_size[0], img_size[1], img_channel), weights=None, include_top=False) # 가중치 체크포인트 파일을 불러오므로 None으로 설정

x = resnet.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu')(x)
predictions = layers.Dense(16, activation='softmax')(x) # 클래스 개수만큼 조정

model = models.Model(inputs=resnet.input, outputs=predictions)

# 이전에 저장된 모델 가중치 불러오기
model.load_weights('/content/drive/MyDrive/checkpoints/model-029.h5') # 경로 작성

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

checkpoint_filepath = '/content/drive/MyDrive/checkpoints2-1/model-{epoch:03d}.h5'

checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    save_best_only=False,
    save_weights_only=True,
    verbose=1)

early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True)

# 학습 이어서 시작
history = model.fit(train_generator,
          steps_per_epoch=len(train_generator),
          epochs=50,
          validation_data=validation_generator,
          validation_steps=len(validation_generator),
          callbacks=[checkpoint_callback, early_stopping_callback],
          initial_epoch=29) # initial_epoch = 이전에 중단된 epoch 숫자

# %%
import matplotlib.pyplot as plt
import numpy as np

# 학습 곡선 그리기
num_epochs = len(history.history['accuracy'])
epoch_range = np.arange(1, num_epochs + 1)

plt.plot(epoch_range, history.history['accuracy'])
plt.plot(epoch_range, history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(epoch_range, history.history['loss'])
plt.plot(epoch_range, history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# 구글 드라이브에 모델 저장
model.save('/content/drive/MyDrive/ResNet101_4class.h5')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt

# 테스트 데이터 폴더 경로
test_dir = '/content/drive/MyDrive/test'

image_size = (224, 224)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=1,
    shuffle=False,
    class_mode='categorical')

# 저장된 모델 경로
model = load_model('/content/drive/MyDrive/ResNet101_4class.h5')

# 분류 및 평가
Y_pred = model.predict(test_generator, steps=len(test_generator))
y_pred = np.argmax(Y_pred, axis=1)

true_labels = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# 출력
print('테스트 결과')
print('---------------------')
for i, filename in enumerate(test_generator.filenames):
    print('{} : {}'.format(filename, class_labels[y_pred[i]]))

accuracy = accuracy_score(true_labels, y_pred)
precision = precision_score(true_labels, y_pred, average='macro')
recall = recall_score(true_labels, y_pred, average='macro')
f1score = f1_score(true_labels, y_pred, average='macro')

print('---------------------')
print('정확도 : {:.2f}'.format(accuracy))
print('정밀도 : {:.2f}'.format(precision))
print('재현율 : {:.2f}'.format(recall))
print('F1-score : {:.2f}'.format(f1score))
# Out:
# Found 349 images belonging to 4 classes.
# 349/349 [==============================] - 77s 215ms/step
# 테스트 결과
# ---------------------
# back/back_left0.jpg : back
# back/back_left100.jpg : back
# back/back_left107.jpg : back
# back/back_left128.jpg : back
# back/back_left138.jpg : right
# back/back_left146.jpg : back
# back/back_left16.jpg : back
# back/back_left162.jpg : right
# back/back_left165.jpg : back
# back/back_left170.jpg : right
# back/back_left18.jpg : back
# back/back_left180.jpg : back
# back/back_left195.jpg : back
# back/back_left200.jpg : back
# back/back_left50.jpg : back
# back/back_left54.jpg : back
# back/back_left74.jpg : back
# back/back_left83.jpg : back
# back/back_left92.jpg : back
# back/back_left94.jpg : back
# back/back_left97.jpg : back
# back/back_left_hurray102.jpg : back
# back/back_left_hurray109.jpg : back
# back/back_left_hurray123.jpg : back
# back/back_left_hurray143.jpg : back
# back/back_left_hurray156.jpg : right
# back/back_left_hurray170.jpg : back
# back/back_left_hurray174.jpg : back
# back/back_left_hurray183.jpg : back
# back/back_left_hurray187.jpg : back
# back/back_left_hurray189.jpg : back
# back/back_left_hurray194.jpg : back
# back/back_left_hurray196.jpg : back
# back/back_left_hurray20.jpg : back
# back/back_left_hurray201.jpg : back
# back/back_left_hurray21.jpg : back
# back/back_left_hurray3.jpg : back
# back/back_left_hurray34.jpg : back
# back/back_left_hurray44.jpg : back
# back/back_left_hurray5.jpg : back
# back/back_left_hurray59.jpg : back
# back/back_left_hurray63.jpg : back
# back/back_left_hurray95.jpg : back
# back/back_left_left117.jpg : right
# back/back_left_left119.jpg : right
# back/back_left_left146.jpg : right
# back/back_left_left149.jpg : right
# back/back_left_left156.jpg : right
# back/back_left_left158.jpg : right
# back/back_left_left170.jpg : right
# back/back_left_left183.jpg : right
# back/back_left_left184.jpg : right
# back/back_left_left196.jpg : right
# back/back_left_left199.jpg : right
# back/back_left_left28.jpg : back
# back/back_left_left32.jpg : back
# back/back_left_left33.jpg : back
# back/back_left_left44.jpg : back
# back/back_left_left46.jpg : back
# back/back_left_left47.jpg : back
# back/back_left_left49.jpg : back
# back/back_left_left53.jpg : back
# back/back_left_left58.jpg : back
# back/back_left_left60.jpg : back
# back/back_left_left67.jpg : back
# back/back_left_right105.jpg : back
# back/back_left_right117.jpg : back
# back/back_left_right121.jpg : back
# back/back_left_right123.jpg : back
# back/back_left_right135.jpg : back
# back/back_left_right146.jpg : back
# back/back_left_right149.jpg : back
# back/back_left_right150.jpg : back
# back/back_left_right155.jpg : back
# back/back_left_right160.jpg : back
# back/back_left_right163.jpg : back
# back/back_left_right167.jpg : back
# back/back_left_right168.jpg : back
# back/back_left_right196.jpg : back
# back/back_left_right201.jpg : back
# back/back_left_right204.jpg : back
# back/back_left_right64.jpg : back
# back/back_left_right8.jpg : back
# back/back_left_right84.jpg : back
# back/back_left_right94.jpg : back
# back/back_left_right95.jpg : back
# back/back_right107.jpg : back
# back/back_right12.jpg : back
# back/back_right120.jpg : back
# back/back_right123.jpg : back
# back/back_right134.jpg : back
# back/back_right136.jpg : back
# back/back_right138.jpg : back
# back/back_right148.jpg : back
# back/back_right149.jpg : back
# back/back_right165.jpg : back
# back/back_right2.jpg : back
# back/back_right22.jpg : back
# back/back_right23.jpg : back
# back/back_right43.jpg : back
# back/back_right44.jpg : back
# back/back_right56.jpg : back
# back/back_right65.jpg : back
# back/back_right68.jpg : back
# back/back_right69.jpg : back
# back/back_right82.jpg : back
# back/back_right88.jpg : back
# back/back_right89.jpg : back
# back/back_right_hurray0.jpg : back
# back/back_right_hurray101.jpg : back
# back/back_right_hurray109.jpg : back
# back/back_right_hurray113.jpg : back
# back/back_right_hurray115.jpg : back
# back/back_right_hurray129.jpg : back
# back/back_right_hurray142.jpg : back
# back/back_right_hurray156.jpg : back
# back/back_right_hurray157.jpg : back
# back/back_right_hurray16.jpg : back
# back/back_right_hurray161.jpg : back
# back/back_right_hurray181.jpg : back
# back/back_right_hurray19.jpg : back
# back/back_right_hurray194.jpg : back
# back/back_right_hurray197.jpg : back
# back/back_right_hurray25.jpg : back
# back/back_right_hurray29.jpg : back
# back/back_right_hurray30.jpg : back
# back/back_right_hurray48.jpg : back
# back/back_right_hurray63.jpg : back
# back/back_right_hurray66.jpg : back
# back/back_right_hurray85.jpg : back
# back/back_right_left101.jpg : right
# back/back_right_left107.jpg : back
# back/back_right_left11.jpg : back
# back/back_right_left115.jpg : back
# back/back_right_left134.jpg : back
# back/back_right_left136.jpg : back
# back/back_right_left137.jpg : back
# back/back_right_left16.jpg : back
# back/back_right_left161.jpg : back
# back/back_right_left172.jpg : back
# back/back_right_left185.jpg : back
# back/back_right_left188.jpg : back
# back/back_right_left197.jpg : back
# back/back_right_left25.jpg : back
# back/back_right_left32.jpg : back
# back/back_right_left41.jpg : back
# back/back_right_left45.jpg : back
# back/back_right_left47.jpg : back
# back/back_right_left53.jpg : back
# back/back_right_left64.jpg : back
# back/back_right_left67.jpg : back
# back/back_right_left9.jpg : back
# back/back_right_right1.jpg : back
# back/back_right_right112.jpg : back
# back/back_right_right129.jpg : back
# back/back_right_right135.jpg : back
# back/back_right_right140.jpg : back
# back/back_right_right154.jpg : back
# back/back_right_right156.jpg : back
# back/back_right_right16.jpg : right
# back/back_right_right167.jpg : back
# back/back_right_right182.jpg : back
# back/back_right_right187.jpg : back
# back/back_right_right190.jpg : back
# back/back_right_right22.jpg : right
# back/back_right_right26.jpg : back
# back/back_right_right32.jpg : back
# back/back_right_right39.jpg : back
# back/back_right_right43.jpg : back
# back/back_right_right51.jpg : back
# back/back_right_right55.jpg : back
# back/back_right_right56.jpg : back
# back/back_right_right85.jpg : back
# back/back_right_right87.jpg : back
# front/front116.jpg : front
# front/front124.jpg : front
# front/front126.jpg : front
# front/front133.jpg : front
# front/front146.jpg : front
# front/front150.jpg : front
# front/front17.jpg : front
# front/front176.jpg : front
# front/front183.jpg : front
# front/front193.jpg : front
# front/front196.jpg : front
# front/front207.jpg : front
# front/front22.jpg : back
# front/front38.jpg : back
# front/front47.jpg : back
# front/front54.jpg : back
# front/front62.jpg : back
# front/front63.jpg : back
# front/front68.jpg : front
# front/front8.jpg : front
# front/front81.jpg : front
# front/front96.jpg : front
# front/front_hurray107.jpg : back
# front/front_hurray108.jpg : back
# front/front_hurray12.jpg : front
# front/front_hurray130.jpg : back
# front/front_hurray131.jpg : back
# front/front_hurray15.jpg : back
# front/front_hurray152.jpg : back
# front/front_hurray173.jpg : back
# front/front_hurray175.jpg : back
# front/front_hurray176.jpg : back
# front/front_hurray19.jpg : front
# front/front_hurray192.jpg : back
# front/front_hurray27.jpg : front
# front/front_hurray35.jpg : back
# front/front_hurray36.jpg : back
# front/front_hurray41.jpg : back
# front/front_hurray49.jpg : back
# front/front_hurray73.jpg : front
# front/front_hurray77.jpg : back
# front/front_hurray84.jpg : back
# front/front_hurray87.jpg : back
# front/front_hurray89.jpg : back
# front/front_left_raised100.jpg : front
# front/front_left_raised105.jpg : front
# front/front_left_raised124.jpg : front
# front/front_left_raised139.jpg : back
# front/front_left_raised143.jpg : back
# front/front_left_raised159.jpg : back
# front/front_left_raised163.jpg : back
# front/front_left_raised169.jpg : back
# front/front_left_raised182.jpg : back
# front/front_left_raised193.jpg : back
# front/front_left_raised207.jpg : back
# front/front_left_raised23.jpg : back
# front/front_left_raised25.jpg : back
# front/front_left_raised29.jpg : back
# front/front_left_raised34.jpg : back
# front/front_left_raised44.jpg : front
# front/front_left_raised58.jpg : front
# front/front_left_raised74.jpg : front
# front/front_left_raised79.jpg : front
# front/front_left_raised8.jpg : back
# front/front_left_raised89.jpg : front
# front/front_left_raised97.jpg : front
# front/front_right_raised10.jpg : back
# front/front_right_raised121.jpg : back
# front/front_right_raised122.jpg : back
# front/front_right_raised131.jpg : back
# front/front_right_raised139.jpg : back
# front/front_right_raised171.jpg : back
# front/front_right_raised172.jpg : back
# front/front_right_raised182.jpg : back
# front/front_right_raised187.jpg : back
# front/front_right_raised198.jpg : back
# front/front_right_raised200.jpg : back
# front/front_right_raised31.jpg : front
# front/front_right_raised42.jpg : front
# front/front_right_raised56.jpg : back
# front/front_right_raised57.jpg : back
# front/front_right_raised59.jpg : back
# front/front_right_raised6.jpg : back
# front/front_right_raised76.jpg : back
# front/front_right_raised77.jpg : back
# front/front_right_raised80.jpg : back
# front/front_right_raised94.jpg : back
# front/front_right_raised97.jpg : back
# left/left112.jpg : back
# left/left146.jpg : back
# left/left158.jpg : back
# left/left178.jpg : right
# left/left190.jpg : right
# left/left20.jpg : back
# left/left204.jpg : back
# left/left21.jpg : back
# left/left22.jpg : back
# left/left24.jpg : back
# left/left29.jpg : right
# left/left3.jpg : right
# left/left4.jpg : right
# left/left45.jpg : back
# left/left47.jpg : right
# left/left5.jpg : right
# left/left50.jpg : right
# left/left62.jpg : right
# left/left74.jpg : right
# left/left89.jpg : right
# left/left9.jpg : right
# left/left97.jpg : right
# left/left_chopping0.jpg : right
# left/left_chopping114.jpg : right
# left/left_chopping129.jpg : right
# left/left_chopping130.jpg : right
# left/left_chopping132.jpg : right
# left/left_chopping147.jpg : right
# left/left_chopping155.jpg : right
# left/left_chopping167.jpg : right
# left/left_chopping168.jpg : right
# left/left_chopping194.jpg : back
# left/left_chopping22.jpg : right
# left/left_chopping30.jpg : right
# left/left_chopping34.jpg : right
# left/left_chopping37.jpg : right
# left/left_chopping39.jpg : right
# left/left_chopping42.jpg : right
# left/left_chopping47.jpg : right
# left/left_chopping49.jpg : right
# left/left_chopping54.jpg : right
# left/left_chopping59.jpg : right
# left/left_chopping6.jpg : right
# left/left_chopping95.jpg : right
# right/right0.jpg : right
# right/right106.jpg : right
# right/right112.jpg : front
# right/right127.jpg : right
# right/right131.jpg : back
# right/right135.jpg : back
# right/right148.jpg : back
# right/right149.jpg : right
# right/right15.jpg : right
# right/right156.jpg : back
# right/right160.jpg : back
# right/right163.jpg : back
# right/right166.jpg : back
# right/right169.jpg : back
# right/right178.jpg : right
# right/right197.jpg : back
# right/right201.jpg : right
# right/right211.jpg : back
# right/right46.jpg : right
# right/right53.jpg : right
# right/right58.jpg : right
# right/right91.jpg : right
# right/right_chopping121.jpg : right
# right/right_chopping125.jpg : right
# right/right_chopping134.jpg : right
# right/right_chopping143.jpg : right
# right/right_chopping153.jpg : right
# right/right_chopping162.jpg : right
# right/right_chopping174.jpg : right
# right/right_chopping183.jpg : right
# right/right_chopping208.jpg : right
# right/right_chopping25.jpg : right
# right/right_chopping38.jpg : right
# right/right_chopping40.jpg : right
# right/right_chopping46.jpg : right
# right/right_chopping55.jpg : right
# right/right_chopping69.jpg : right
# right/right_chopping72.jpg : right
# right/right_chopping78.jpg : right
# right/right_chopping84.jpg : right
# right/right_chopping88.jpg : right
# right/right_chopping9.jpg : right
# right/right_chopping98.jpg : right
# ---------------------
# 정확도 : 0.63
# 정밀도 : 0.50
# 재현율 : 0.50
# F1-score : 0.45
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
