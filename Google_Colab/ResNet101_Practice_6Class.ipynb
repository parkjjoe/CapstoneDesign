# %%
# !pip install tensorflow==2.6.0
import tensorflow as tf
print(tf.__version__)

# %%
# !pip install tensorflow==2.6.0 keras==2.6.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import metrics

# 데이터 경로
train_dir = '/content/drive/MyDrive/datasets2/train'
val_dir = '/content/drive/MyDrive/datasets2/val'

# 이미지 크기 및 채널
img_size = (224, 224)
img_channel = 3

# 이미지 데이터 전처리
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    brightness_range=(0.8,1.8),
    fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

# ResNet101 모델 불러오기
resnet = ResNet101(input_shape=(img_size[0], img_size[1], img_channel), weights='imagenet', include_top=False) # ImageNet으로 사전 학습된 가중치를 초기 가중치로 사용

# 새로운 분류층 추가
x = resnet.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu')(x)
predictions = layers.Dense(6, activation='softmax')(x) # 클래스 개수만큼 조정

model = models.Model(inputs=resnet.input, outputs=predictions)

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 체크포인트를 저장할 경로
checkpoint_filepath = '/content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-{epoch:03d}.h5'

# 체크포인트 콜백 설정
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    save_best_only=False,
    save_weights_only=True,
    verbose=1)

# 모델 학습
history = model.fit(train_generator,
          steps_per_epoch=len(train_generator),
          epochs=50,
          validation_data=validation_generator,
          validation_steps=len(validation_generator),
          callbacks=[checkpoint_callback]) # 체크포인트 인자 추가
# Out:
# Found 7213 images belonging to 6 classes.
# Found 1968 images belonging to 6 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step
# Epoch 1/50
# 451/451 [==============================] - ETA: 0s - loss: 1.0824 - accuracy: 0.5626
# Epoch 1: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-001.h5
# 451/451 [==============================] - 2283s 5s/step - loss: 1.0824 - accuracy: 0.5626 - val_loss: 6.3079 - val_accuracy: 0.1540
# Epoch 2/50
# 451/451 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.9213
# Epoch 2: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-002.h5
# 451/451 [==============================] - 333s 739ms/step - loss: 0.2294 - accuracy: 0.9213 - val_loss: 18.5297 - val_accuracy: 0.1524
# Epoch 3/50
# 451/451 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9602
# Epoch 3: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-003.h5
# 451/451 [==============================] - 330s 731ms/step - loss: 0.1185 - accuracy: 0.9602 - val_loss: 0.2092 - val_accuracy: 0.9299
# Epoch 4/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9709
# Epoch 4: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-004.h5
# 451/451 [==============================] - 330s 731ms/step - loss: 0.0879 - accuracy: 0.9709 - val_loss: 0.0550 - val_accuracy: 0.9812
# Epoch 5/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9730
# Epoch 5: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-005.h5
# 451/451 [==============================] - 332s 735ms/step - loss: 0.0796 - accuracy: 0.9730 - val_loss: 0.2817 - val_accuracy: 0.9045
# Epoch 6/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9823
# Epoch 6: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-006.h5
# 451/451 [==============================] - 326s 723ms/step - loss: 0.0557 - accuracy: 0.9823 - val_loss: 0.5998 - val_accuracy: 0.8161
# Epoch 7/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9820
# Epoch 7: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-007.h5
# 451/451 [==============================] - 325s 720ms/step - loss: 0.0538 - accuracy: 0.9820 - val_loss: 0.4770 - val_accuracy: 0.8049
# Epoch 8/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9889
# Epoch 8: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-008.h5
# 451/451 [==============================] - 329s 728ms/step - loss: 0.0354 - accuracy: 0.9889 - val_loss: 1.4412 - val_accuracy: 0.5666
# Epoch 9/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9913
# Epoch 9: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-009.h5
# 451/451 [==============================] - 325s 720ms/step - loss: 0.0231 - accuracy: 0.9913 - val_loss: 0.5956 - val_accuracy: 0.7922
# Epoch 10/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9906
# Epoch 10: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-010.h5
# 451/451 [==============================] - 326s 722ms/step - loss: 0.0291 - accuracy: 0.9906 - val_loss: 0.0748 - val_accuracy: 0.9812
# Epoch 11/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9914
# Epoch 11: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-011.h5
# 451/451 [==============================] - 325s 720ms/step - loss: 0.0304 - accuracy: 0.9914 - val_loss: 5.2653 - val_accuracy: 0.1524
# Epoch 12/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9904
# Epoch 12: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-012.h5
# 451/451 [==============================] - 327s 725ms/step - loss: 0.0343 - accuracy: 0.9904 - val_loss: 0.2733 - val_accuracy: 0.8999
# Epoch 13/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9981
# Epoch 13: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-013.h5
# 451/451 [==============================] - 327s 724ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0904 - val_accuracy: 0.9700
# Epoch 14/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9867
# Epoch 14: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-014.h5
# 451/451 [==============================] - 325s 721ms/step - loss: 0.0425 - accuracy: 0.9867 - val_loss: 1.0391 - val_accuracy: 0.6972
# Epoch 15/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9936
# Epoch 15: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-015.h5
# 451/451 [==============================] - 324s 718ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 1.4524 - val_accuracy: 0.5788
# Epoch 16/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9947
# Epoch 16: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-016.h5
# 451/451 [==============================] - 324s 718ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.4980 - val_accuracy: 0.8267
# Epoch 17/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9971
# Epoch 17: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-017.h5
# 451/451 [==============================] - 323s 717ms/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.6592 - val_accuracy: 0.7403
# Epoch 18/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9954
# Epoch 18: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-018.h5
# 451/451 [==============================] - 323s 715ms/step - loss: 0.0124 - accuracy: 0.9954 - val_loss: 7.8136 - val_accuracy: 0.1662
# Epoch 19/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9917
# Epoch 19: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-019.h5
# 451/451 [==============================] - 320s 710ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 0.0083 - val_accuracy: 0.9980
# Epoch 20/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9954
# Epoch 20: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-020.h5
# 451/451 [==============================] - 321s 711ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 21/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9922
# Epoch 21: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-021.h5
# 451/451 [==============================] - 322s 713ms/step - loss: 0.0280 - accuracy: 0.9922 - val_loss: 1.5771e-04 - val_accuracy: 1.0000
# Epoch 22/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9969
# Epoch 22: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-022.h5
# 451/451 [==============================] - 321s 711ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 23/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9935
# Epoch 23: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-023.h5
# 451/451 [==============================] - 325s 721ms/step - loss: 0.0237 - accuracy: 0.9935 - val_loss: 0.0115 - val_accuracy: 0.9964
# Epoch 24/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9989
# Epoch 24: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-024.h5
# 451/451 [==============================] - 326s 722ms/step - loss: 0.0025 - accuracy: 0.9989 - val_loss: 3.1847e-06 - val_accuracy: 1.0000
# Epoch 25/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9907
# Epoch 25: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-025.h5
# 451/451 [==============================] - 326s 723ms/step - loss: 0.0293 - accuracy: 0.9907 - val_loss: 4.1065 - val_accuracy: 0.2215
# Epoch 26/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9975
# Epoch 26: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-026.h5
# 451/451 [==============================] - 327s 726ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 1.8677e-05 - val_accuracy: 1.0000
# Epoch 27/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 27: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-027.h5
# 451/451 [==============================] - 323s 716ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 5.5694e-06 - val_accuracy: 1.0000
# Epoch 28/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9925
# Epoch 28: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-028.h5
# 451/451 [==============================] - 320s 710ms/step - loss: 0.0250 - accuracy: 0.9925 - val_loss: 0.4595 - val_accuracy: 0.8913
# Epoch 29/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9969
# Epoch 29: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-029.h5
# 451/451 [==============================] - 320s 710ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.0098 - val_accuracy: 0.9970
# Epoch 30/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9949
# Epoch 30: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-030.h5
# 451/451 [==============================] - 321s 712ms/step - loss: 0.0200 - accuracy: 0.9949 - val_loss: 0.0642 - val_accuracy: 0.9802
# Epoch 31/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 31: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-031.h5
# 451/451 [==============================] - 321s 711ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 1.6263e-04 - val_accuracy: 1.0000
# Epoch 32/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9943
# Epoch 32: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-032.h5
# 451/451 [==============================] - 321s 710ms/step - loss: 0.0177 - accuracy: 0.9943 - val_loss: 2.3762 - val_accuracy: 0.6082
# Epoch 33/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9947
# Epoch 33: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-033.h5
# 451/451 [==============================] - 322s 714ms/step - loss: 0.0201 - accuracy: 0.9947 - val_loss: 0.0027 - val_accuracy: 0.9990
# Epoch 34/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 34: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-034.h5
# 451/451 [==============================] - 322s 713ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 6.9387e-07 - val_accuracy: 1.0000
# Epoch 35/50
# 451/451 [==============================] - ETA: 0s - loss: 3.9034e-04 - accuracy: 0.9999
# Epoch 35: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-035.h5
# 451/451 [==============================] - 322s 713ms/step - loss: 3.9034e-04 - accuracy: 0.9999 - val_loss: 1.4650 - val_accuracy: 0.7698
# Epoch 36/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9949
# Epoch 36: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-036.h5
# 451/451 [==============================] - 321s 711ms/step - loss: 0.0185 - accuracy: 0.9949 - val_loss: 6.3688 - val_accuracy: 0.3613
# Epoch 37/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9986
# Epoch 37: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-037.h5
# 451/451 [==============================] - 322s 715ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 1.1139e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9979
# Epoch 38: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-038.h5
# 451/451 [==============================] - 320s 709ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 2.0284 - val_accuracy: 0.6560
# Epoch 39/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9936
# Epoch 39: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-039.h5
# 451/451 [==============================] - 322s 714ms/step - loss: 0.0218 - accuracy: 0.9936 - val_loss: 0.5789 - val_accuracy: 0.8232
# Epoch 40/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9979
# Epoch 40: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-040.h5
# 451/451 [==============================] - 319s 707ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.6502 - val_accuracy: 0.7962
# Epoch 41/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9985
# Epoch 41: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-041.h5
# 451/451 [==============================] - 320s 708ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 1.9849e-05 - val_accuracy: 1.0000
# Epoch 42/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9967
# Epoch 42: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-042.h5
# 451/451 [==============================] - 319s 708ms/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 1.2803 - val_accuracy: 0.6900
# Epoch 43/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9982
# Epoch 43: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-043.h5
# 451/451 [==============================] - 320s 708ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 2.8879e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9976
# Epoch 44: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-044.h5
# 451/451 [==============================] - 321s 711ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 8.3009e-05 - val_accuracy: 1.0000
# Epoch 45/50
# 451/451 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 45: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-045.h5
# 451/451 [==============================] - 319s 707ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 1.0511e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 451/451 [==============================] - ETA: 0s - loss: 1.9575e-04 - accuracy: 1.0000
# Epoch 46: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-046.h5
# 451/451 [==============================] - 319s 706ms/step - loss: 1.9575e-04 - accuracy: 1.0000 - val_loss: 3.4949 - val_accuracy: 0.4741
# Epoch 47/50
# 451/451 [==============================] - ETA: 0s - loss: 1.8727e-04 - accuracy: 1.0000
# Epoch 47: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-047.h5
# 451/451 [==============================] - 320s 709ms/step - loss: 1.8727e-04 - accuracy: 1.0000 - val_loss: 2.8935e-06 - val_accuracy: 1.0000
# Epoch 48/50
# 451/451 [==============================] - ETA: 0s - loss: 7.2038e-05 - accuracy: 1.0000
# Epoch 48: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-048.h5
# 451/451 [==============================] - 320s 708ms/step - loss: 7.2038e-05 - accuracy: 1.0000 - val_loss: 2.6643e-07 - val_accuracy: 1.0000
# Epoch 49/50
# 451/451 [==============================] - ETA: 0s - loss: 1.4871e-04 - accuracy: 1.0000
# Epoch 49: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-049.h5
# 451/451 [==============================] - 317s 703ms/step - loss: 1.4871e-04 - accuracy: 1.0000 - val_loss: 3.3871e-07 - val_accuracy: 1.0000
# Epoch 50/50
# 451/451 [==============================] - ETA: 0s - loss: 2.2595e-05 - accuracy: 1.0000
# Epoch 50: saving model to /content/drive/MyDrive/checkpoint/checkpoints_class_reduced/model-050.h5
# 451/451 [==============================] - 318s 706ms/step - loss: 2.2595e-05 - accuracy: 1.0000 - val_loss: 1.2393e-07 - val_accuracy: 1.0000

# %%
from tensorflow.keras.callbacks import EarlyStopping

# 조기 종료 콜백 설정
early_stopping_callback = EarlyStopping(
    monitor='val_loss', # 검증 손실을 기준으로 조기 종료를 판단합니다.
    patience=5, # 검증 손실이 최소 5 에포크 동안 개선되지 않으면 학습을 중단합니다.
    restore_best_weights=True) # 가장 낮은 검증 손실을 가진 모델의 가중치를 복원합니다.

# 모델 학습
history = model.fit(train_generator,
          steps_per_epoch=len(train_generator),
          epochs=100,
          validation_data=validation_generator,
          validation_steps=len(validation_generator),
          callbacks=[checkpoint_callback, early_stopping_callback]) # EarlyStopping 콜백을 callbacks 인자에 추가합니다.

# 모델 학습 코드에 추가

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101
from tensorflow.keras import layers, models
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import ModelCheckpoint

train_dir = '/content/drive/MyDrive/dataset/train'
val_dir = '/content/drive/MyDrive/dataset/val'

img_size = (224, 224)
img_channel = 3

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    brightness_range=(0.8,1.8),
    fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical') # categorical, binary, sparse 선택

resnet = ResNet101(input_shape=(img_size[0], img_size[1], img_channel), weights=None, include_top=False) # 가중치 체크포인트 파일을 불러오므로 None으로 설정

x = resnet.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu')(x)
predictions = layers.Dense(16, activation='softmax')(x) # 클래스 개수만큼 조정

model = models.Model(inputs=resnet.input, outputs=predictions)

# 이전에 저장된 모델 가중치 불러오기
model.load_weights('/content/drive/MyDrive/checkpoints/model-049.h5') # 경로 작성

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

checkpoint_filepath = '/content/drive/MyDrive/checkpoints/model-{epoch:03d}.h5'

checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    save_best_only=False,
    save_weights_only=True,
    verbose=1)

# 학습 이어서 시작
history = model.fit(train_generator,
          steps_per_epoch=len(train_generator),
          epochs=100,
          validation_data=validation_generator,
          validation_steps=len(validation_generator),
          callbacks=[checkpoint_callback],
          initial_epoch=49) # initial_epoch = 이전에 중단된 epoch 숫자

# %%
import matplotlib.pyplot as plt
import numpy as np

# 학습 곡선 그리기
num_epochs = len(history.history['accuracy'])
epoch_range = np.arange(1, num_epochs + 1)

plt.plot(epoch_range, history.history['accuracy'])
plt.plot(epoch_range, history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(epoch_range, history.history['loss'])
plt.plot(epoch_range, history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# 구글 드라이브에 모델 저장
model.save('/content/drive/MyDrive/ResNet101_6class.h5')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt

# 테스트 데이터 폴더 경로
test_dir = '/content/drive/MyDrive/test'

image_size = (224, 224)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=1,
    shuffle=False,
    class_mode='categorical')

# 저장된 모델 경로
model = load_model('/content/drive/MyDrive/ResNet101_6class.h5')

# 분류 및 평가
Y_pred = model.predict(test_generator, steps=len(test_generator))
y_pred = np.argmax(Y_pred, axis=1)

true_labels = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# 출력
print('테스트 결과')
print('---------------------')
for i, filename in enumerate(test_generator.filenames):
    print('{} : {}'.format(filename, class_labels[y_pred[i]]))

accuracy = accuracy_score(true_labels, y_pred)
precision = precision_score(true_labels, y_pred, average='macro')
recall = recall_score(true_labels, y_pred, average='macro')
f1score = f1_score(true_labels, y_pred, average='macro')

print('---------------------')
print('정확도 : {:.2f}'.format(accuracy))
print('정밀도 : {:.2f}'.format(precision))
print('재현율 : {:.2f}'.format(recall))
print('F1-score : {:.2f}'.format(f1score))
# Out:
# Found 349 images belonging to 6 classes.
# 349/349 [==============================] - 76s 214ms/step
# 테스트 결과
# ---------------------
# back_left/back_left0.jpg : back_left
# back_left/back_left100.jpg : left
# back_left/back_left107.jpg : back_left
# back_left/back_left128.jpg : back_left
# back_left/back_left138.jpg : back_right
# back_left/back_left146.jpg : back_left
# back_left/back_left16.jpg : back_left
# back_left/back_left162.jpg : back_left
# back_left/back_left165.jpg : back_left
# back_left/back_left170.jpg : back_left
# back_left/back_left18.jpg : back_left
# back_left/back_left180.jpg : back_left
# back_left/back_left195.jpg : back_left
# back_left/back_left200.jpg : back_left
# back_left/back_left50.jpg : back_left
# back_left/back_left54.jpg : back_left
# back_left/back_left74.jpg : back_left
# back_left/back_left83.jpg : left
# back_left/back_left92.jpg : back_left
# back_left/back_left94.jpg : left
# back_left/back_left97.jpg : left
# back_left/back_left_hurray102.jpg : back_left
# back_left/back_left_hurray109.jpg : back_left
# back_left/back_left_hurray123.jpg : back_left
# back_left/back_left_hurray143.jpg : back_left
# back_left/back_left_hurray156.jpg : back_left
# back_left/back_left_hurray170.jpg : back_left
# back_left/back_left_hurray174.jpg : back_left
# back_left/back_left_hurray183.jpg : back_left
# back_left/back_left_hurray187.jpg : back_left
# back_left/back_left_hurray189.jpg : back_left
# back_left/back_left_hurray194.jpg : back_left
# back_left/back_left_hurray196.jpg : back_left
# back_left/back_left_hurray20.jpg : back_left
# back_left/back_left_hurray201.jpg : back_left
# back_left/back_left_hurray21.jpg : back_left
# back_left/back_left_hurray3.jpg : back_left
# back_left/back_left_hurray34.jpg : back_left
# back_left/back_left_hurray44.jpg : back_left
# back_left/back_left_hurray5.jpg : back_left
# back_left/back_left_hurray59.jpg : back_left
# back_left/back_left_hurray63.jpg : back_left
# back_left/back_left_hurray95.jpg : back_left
# back_left/back_left_left117.jpg : back_left
# back_left/back_left_left119.jpg : back_left
# back_left/back_left_left146.jpg : back_left
# back_left/back_left_left149.jpg : back_left
# back_left/back_left_left156.jpg : back_left
# back_left/back_left_left158.jpg : back_left
# back_left/back_left_left170.jpg : back_left
# back_left/back_left_left183.jpg : back_left
# back_left/back_left_left184.jpg : back_left
# back_left/back_left_left196.jpg : back_left
# back_left/back_left_left199.jpg : back_left
# back_left/back_left_left28.jpg : back_left
# back_left/back_left_left32.jpg : back_left
# back_left/back_left_left33.jpg : back_left
# back_left/back_left_left44.jpg : back_left
# back_left/back_left_left46.jpg : back_left
# back_left/back_left_left47.jpg : back_left
# back_left/back_left_left49.jpg : back_left
# back_left/back_left_left53.jpg : back_left
# back_left/back_left_left58.jpg : back_left
# back_left/back_left_left60.jpg : back_left
# back_left/back_left_left67.jpg : back_left
# back_left/back_left_right105.jpg : back_left
# back_left/back_left_right117.jpg : back_left
# back_left/back_left_right121.jpg : back_left
# back_left/back_left_right123.jpg : back_left
# back_left/back_left_right135.jpg : back_left
# back_left/back_left_right146.jpg : back_left
# back_left/back_left_right149.jpg : back_left
# back_left/back_left_right150.jpg : back_left
# back_left/back_left_right155.jpg : back_left
# back_left/back_left_right160.jpg : back_left
# back_left/back_left_right163.jpg : back_left
# back_left/back_left_right167.jpg : back_left
# back_left/back_left_right168.jpg : back_left
# back_left/back_left_right196.jpg : back_left
# back_left/back_left_right201.jpg : back_left
# back_left/back_left_right204.jpg : back_left
# back_left/back_left_right64.jpg : back_left
# back_left/back_left_right8.jpg : back_left
# back_left/back_left_right84.jpg : back_left
# back_left/back_left_right94.jpg : back_left
# back_left/back_left_right95.jpg : back_left
# back_right/back_right107.jpg : back_left
# back_right/back_right12.jpg : back_right
# back_right/back_right120.jpg : back_right
# back_right/back_right123.jpg : back_right
# back_right/back_right134.jpg : back_right
# back_right/back_right136.jpg : back_right
# back_right/back_right138.jpg : back_right
# back_right/back_right148.jpg : back_right
# back_right/back_right149.jpg : back_right
# back_right/back_right165.jpg : back_right
# back_right/back_right2.jpg : back_right
# back_right/back_right22.jpg : back_right
# back_right/back_right23.jpg : back_right
# back_right/back_right43.jpg : back_right
# back_right/back_right44.jpg : back_right
# back_right/back_right56.jpg : left
# back_right/back_right65.jpg : front
# back_right/back_right68.jpg : left
# front_hurray/front_right_raised57.jpg : back_left
# front_hurray/front_right_raised59.jpg : back_left
# front_hurray/front_right_raised6.jpg : back_left
# front_hurray/front_right_raised76.jpg : back_left
# front_hurray/front_right_raised77.jpg : back_left
# front_hurray/front_right_raised80.jpg : back_left
# front_hurray/front_right_raised94.jpg : back_left
# front_hurray/front_right_raised97.jpg : back_left
# left/left112.jpg : back_right
# left/left146.jpg : back_right
# left/left158.jpg : back_right
# left/left178.jpg : back_right
# left/left190.jpg : back_right
# left/left20.jpg : left
# left/left204.jpg : back_right
# left/left21.jpg : left
# left/left22.jpg : left
# left/left24.jpg : left
# left/left29.jpg : right
# left/left3.jpg : left
# left/left4.jpg : left
# left/left45.jpg : back_left
# left/left47.jpg : front
# left/left5.jpg : left
# left/left50.jpg : back_left
# left/left62.jpg : left
# left/left74.jpg : left
# left/left89.jpg : left
# left/left9.jpg : left
# left/left97.jpg : left
# left/left_chopping0.jpg : left
# left/left_chopping114.jpg : left
# left/left_chopping129.jpg : left
# left/left_chopping130.jpg : left
# left/left_chopping132.jpg : left
# left/left_chopping147.jpg : left
# left/left_chopping155.jpg : left
# left/left_chopping167.jpg : left
# left/left_chopping168.jpg : left
# left/left_chopping194.jpg : back_right
# left/left_chopping22.jpg : left
# left/left_chopping30.jpg : left
# left/left_chopping34.jpg : left
# left/left_chopping37.jpg : left
# left/left_chopping39.jpg : left
# left/left_chopping42.jpg : left
# left/left_chopping47.jpg : left
# left/left_chopping49.jpg : left
# left/left_chopping54.jpg : left
# left/left_chopping59.jpg : left
# left/left_chopping6.jpg : left
# left/left_chopping95.jpg : back_right
# right/right0.jpg : right
# right/right106.jpg : right
# right/right112.jpg : right
# right/right127.jpg : right
# right/right131.jpg : right
# right/right135.jpg : right
# right/right148.jpg : right
# right/right149.jpg : right
# right/right15.jpg : right
# right/right156.jpg : right
# right/right160.jpg : right
# right/right163.jpg : right
# right/right166.jpg : right
# right/right169.jpg : right
# right/right178.jpg : right
# right/right197.jpg : right
# right/right201.jpg : right
# right/right211.jpg : right
# right/right46.jpg : right
# right/right53.jpg : left
# right/right58.jpg : right
# right/right91.jpg : right
# right/right_chopping121.jpg : right
# right/right_chopping125.jpg : right
# right/right_chopping134.jpg : right
# right/right_chopping143.jpg : right
# right/right_chopping153.jpg : right
# right/right_chopping162.jpg : right
# right/right_chopping174.jpg : right
# right/right_chopping183.jpg : right
# right/right_chopping208.jpg : right
# right/right_chopping25.jpg : right
# right/right_chopping38.jpg : right
# right/right_chopping40.jpg : right
# right/right_chopping46.jpg : right
# right/right_chopping55.jpg : left
# right/right_chopping69.jpg : left
# right/right_chopping72.jpg : left
# right/right_chopping78.jpg : left
# right/right_chopping84.jpg : left
# right/right_chopping88.jpg : left
# right/right_chopping9.jpg : right
# right/right_chopping98.jpg : left
# ---------------------
# 정확도 : 0.51
# 정밀도 : 0.42
# 재현율 : 0.47
# F1-score : 0.43
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
